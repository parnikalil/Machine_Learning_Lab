# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
df = pd.read_csv("../data/processed/olist_orders_abt.csv")
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#                  customer_unique_id            customer_city customer_state  \
# 0  7c396fd4830fd04220f754e42b4e5bff                sao paulo             SP
# 1  af07308b275d755c9edb36a90c618231                barreiras             BA
# 2  3a653a41f6f9fc3d2a113cf8398680e8               vianopolis             GO
# 3  7c142cf63193a1473d2e66489a9ae977  sao goncalo do amarante             RN
# 4  72632f0f9dd73dfee390c9b22eb56dd6              santo andre             SP
#
#   order_status  order_year  order_month  order_day  order_day_of_week  ...  \
# 0    delivered        2017           10          2                  0  ...
# 1    delivered        2018            7         24                  1  ...
# 2    delivered        2018            8          8                  2  ...
# 3    delivered        2017           11         18                  5  ...
# 4    delivered        2018            2         13                  1  ...
#
#    total_payment_value  max_payment_installments  payment_types_count  \
# 0                38.71                       1.0                  2.0
# 1               141.46                       1.0                  1.0
# 2               179.12                       3.0                  1.0
# 3                72.20                       1.0                  1.0
# 4                28.62                       1.0                  1.0
#
#    dominant_payment_type  total_items  total_price  total_freight  \
# 0                voucher          1.0        29.99           8.72
# 1                 boleto          1.0       118.70          22.76
# 2            credit_card          1.0       159.90          19.22
# 3            credit_card          1.0        45.00          27.20
# 4            credit_card          1.0        19.90           8.72
#
#    unique_products  unique_sellers  main_product_category
# 0              1.0             1.0             housewares
# 1              1.0             1.0              perfumery
# 2              1.0             1.0                   auto
# 3              1.0             1.0               pet_shop
# 4              1.0             1.0             stationery
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (99441, 29)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   order_id                  99441 non-null  str
#  1   customer_id               99441 non-null  str
#  2   customer_unique_id        99441 non-null  str
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
#  5   order_status              99441 non-null  str
#  6   order_year                99441 non-null  int64
#  7   order_month               99441 non-null  int64
#  8   order_day                 99441 non-null  int64
#  9   order_day_of_week         99441 non-null  int64
#  10  order_hour                99441 non-null  int64
#  11  delivery_days             96476 non-null  float64
#  12  estimated_delivery_days   99441 non-null  int64
#  13  delivery_delay_days       96476 non-null  float64
#  14  is_late_delivery          99441 non-null  int64
#  15  review_score              98673 non-null  float64
#  16  is_low_review             99441 non-null  int64
#  17  review_comment_count      98673 non-null  float64
#  18  has_review_comment        98673 non-null  float64
#  19  total_payment_value       99440 non-null  float64
#  20  max_payment_installments  99440 non-null  float64
#  21  payment_types_count       99440 non-null  float64
#  22  dominant_payment_type     99440 non-null  str
#  23  total_items               98666 non-null  float64
#  24  total_price               98666 non-null  float64
#  25  total_freight             98666 non-null  float64
#  26  unique_products           98666 non-null  float64
#  27  unique_sellers            98666 non-null  float64
#  28  main_product_category     97256 non-null  str
# dtypes: float64(13), int64(8), str(8)
# memory usage: 22.0 MB

# %%
df.describe()
# Out:
#          order_year   order_month     order_day  order_day_of_week  \
# count  99441.000000  99441.000000  99441.000000       99441.000000
# mean    2017.539838      6.032220     15.505948           2.755735
# std        0.505007      3.232999      8.667298           1.966495
# min     2016.000000      1.000000      1.000000           0.000000
# 25%     2017.000000      3.000000      8.000000           1.000000
# 50%     2018.000000      6.000000     15.000000           3.000000
# 75%     2018.000000      8.000000     23.000000           4.000000
# max     2018.000000     12.000000     31.000000           6.000000
#
#          order_hour  delivery_days  estimated_delivery_days  \
# count  99441.000000   96476.000000             99441.000000
# mean      14.770829      12.094086                23.403958
# std        5.326800       9.551746                 8.829562
# min        0.000000       0.000000                 1.000000
# 25%       11.000000       6.000000                18.000000
# 50%       15.000000      10.000000                23.000000
# 75%       19.000000      15.000000                28.000000
# max       23.000000     209.000000               155.000000
#
#        delivery_delay_days  is_late_delivery  review_score  ...  \
# count         96476.000000      99441.000000  98673.000000  ...
# mean            -11.876881          0.065717      4.086793  ...
# std              10.183854          0.247789      1.346274  ...
# min            -147.000000          0.000000      1.000000  ...
# 25%             -17.000000          0.000000      4.000000  ...
# 50%             -12.000000          0.000000      5.000000  ...
# 75%              -7.000000          0.000000      5.000000  ...
# max             188.000000          1.000000      5.000000  ...
#
#        review_comment_count  has_review_comment  total_payment_value  \
# count          98673.000000        98673.000000         99440.000000
# mean               0.415281            0.413852           160.990267
# std                0.495685            0.492525           221.951257
# min                0.000000            0.000000             0.000000
# 25%                0.000000            0.000000            62.010000
# 50%                0.000000            0.000000           105.290000
# 75%                1.000000            1.000000           176.970000
# max                3.000000            1.000000         13664.080000
#
#        max_payment_installments  payment_types_count   total_items  \
# count              99440.000000         99440.000000  98666.000000
# mean                   2.930521             1.022586      1.141731
# std                    2.715685             0.148582      0.538452
# min                    0.000000             1.000000      1.000000
# 25%                    1.000000             1.000000      1.000000
# 50%                    2.000000             1.000000      1.000000
# 75%                    4.000000             1.000000      1.000000
# max                   24.000000             2.000000     21.000000
#
#         total_price  total_freight  unique_products  unique_sellers
# count  98666.000000   98666.000000     98666.000000    98666.000000
# mean     137.754076      22.823562         1.038098        1.013622
# std      210.645145      21.650909         0.226456        0.122297
# min        0.850000       0.000000         1.000000        1.000000
# 25%       45.900000      13.850000         1.000000        1.000000
# 50%       86.900000      17.170000         1.000000        1.000000
# 75%      149.900000      24.040000         1.000000        1.000000
# max    13440.000000    1794.960000         8.000000        5.000000
#
# [8 rows x 21 columns]

# %%
nominal_columns = [
    "customer_state",
    "customer_city",
    "main_product_category",
    "dominant_payment_type",
    "order_status"
]

ordinal_columns = [
    "review_score"
]

interval_columns = [
    "order_hour",
    "order_month",
    "order_day_of_week"
]

ratio_columns = [
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "estimated_delivery_days",
    "delivery_delay_days",
    "total_items",
    "unique_products",
    "unique_sellers"
]

# %%
def keep_existing_columns(dataframe, columns):
    return [col for col in columns if col in dataframe.columns]

nominal_columns = keep_existing_columns(df, nominal_columns)
ordinal_columns = keep_existing_columns(df, ordinal_columns)
interval_columns = keep_existing_columns(df, interval_columns)
ratio_columns = keep_existing_columns(df, ratio_columns)

# %%
print("Nominal:", nominal_columns)
print("\nOrdinal:", ordinal_columns)
print("\nInterval:", interval_columns)
print("\nRatio:", ratio_columns)
# Out:
# Nominal: ['customer_state', 'customer_city', 'main_product_category', 'dominant_payment_type', 'order_status']
#
# Ordinal: ['review_score']
#
# Interval: ['order_hour', 'order_month', 'order_day_of_week']
#
# Ratio: ['total_payment_value', 'total_price', 'total_freight', 'delivery_days', 'estimated_delivery_days', 'delivery_delay_days', 'total_items', 'unique_products', 'unique_sellers']

# %%
if "delivery_days" in df.columns:
    df["delivery_speed_category"] = pd.cut(
        df["delivery_days"],
        bins=[-1, 7, 15, 30, np.inf],
        labels=["Fast", "Normal", "Slow", "Very Delayed"]
    )

if "total_payment_value" in df.columns:
    df["payment_value_band"] = pd.qcut(
        df["total_payment_value"],
        q=4,
        labels=["Low", "Medium", "High", "Premium"],
        duplicates="drop"
    )

df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#                  customer_unique_id            customer_city customer_state  \
# 0  7c396fd4830fd04220f754e42b4e5bff                sao paulo             SP
# 1  af07308b275d755c9edb36a90c618231                barreiras             BA
# 2  3a653a41f6f9fc3d2a113cf8398680e8               vianopolis             GO
# 3  7c142cf63193a1473d2e66489a9ae977  sao goncalo do amarante             RN
# 4  72632f0f9dd73dfee390c9b22eb56dd6              santo andre             SP
#
#   order_status  order_year  order_month  order_day  order_day_of_week  ...  \
# 0    delivered        2017           10          2                  0  ...
# 1    delivered        2018            7         24                  1  ...
# 2    delivered        2018            8          8                  2  ...
# 3    delivered        2017           11         18                  5  ...
# 4    delivered        2018            2         13                  1  ...
#
#    payment_types_count  dominant_payment_type  total_items  total_price  \
# 0                  2.0                voucher          1.0        29.99
# 1                  1.0                 boleto          1.0       118.70
# 2                  1.0            credit_card          1.0       159.90
# 3                  1.0            credit_card          1.0        45.00
# 4                  1.0            credit_card          1.0        19.90
#
#    total_freight  unique_products  unique_sellers  main_product_category  \
# 0           8.72              1.0             1.0             housewares
# 1          22.76              1.0             1.0              perfumery
# 2          19.22              1.0             1.0                   auto
# 3          27.20              1.0             1.0               pet_shop
# 4           8.72              1.0             1.0             stationery
#
#    delivery_speed_category  payment_value_band
# 0                   Normal                 Low
# 1                   Normal                High
# 2                   Normal             Premium
# 3                   Normal              Medium
# 4                     Fast                 Low
#
# [5 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# order_id                       0
# customer_id                    0
# customer_unique_id             0
# customer_city                  0
# customer_state                 0
# order_status                   0
# order_year                     0
# order_month                    0
# order_day                      0
# order_day_of_week              0
# order_hour                     0
# delivery_days               2965
# estimated_delivery_days        0
# delivery_delay_days         2965
# is_late_delivery               0
# review_score                 768
# is_low_review                  0
# review_comment_count         768
# has_review_comment           768
# total_payment_value            1
# max_payment_installments       1
# payment_types_count            1
# dominant_payment_type          1
# total_items                  775
# total_price                  775
# total_freight                775
# unique_products              775
# unique_sellers               775
# main_product_category       2185
# delivery_speed_category     2965
# payment_value_band             1
# dtype: int64

# %%
missing_summary = pd.DataFrame({
    "missing_count": df.isnull().sum(),
    "missing_percent": (df.isnull().sum() / len(df)) * 100
}).sort_values(by="missing_percent", ascending=False)

missing_summary.head(20)
# Out:
#                           missing_count  missing_percent
# delivery_delay_days                2965         2.981668
# delivery_days                      2965         2.981668
# delivery_speed_category            2965         2.981668
# main_product_category              2185         2.197283
# total_price                         775         0.779357
# unique_sellers                      775         0.779357
# total_freight                       775         0.779357
# total_items                         775         0.779357
# unique_products                     775         0.779357
# review_score                        768         0.772317
# review_comment_count                768         0.772317
# has_review_comment                  768         0.772317
# total_payment_value                   1         0.001006
# payment_types_count                   1         0.001006
# max_payment_installments              1         0.001006
# payment_value_band                    1         0.001006
# dominant_payment_type                 1         0.001006
# is_late_delivery                      0         0.000000
# order_hour                            0         0.000000
# order_day                             0         0.000000

# %%
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0].sort_values(ascending=False)

sns.barplot(
    x=missing_values.values,
    y=missing_values.index
)

plt.title("Missing Values by Column")
plt.xlabel("Number of Missing Values")
plt.ylabel("Column")
plt.show()

# %%
plt.figure(figsize=(14,6))

sns.heatmap(
    df.isnull(),
    cbar=False
)

plt.title("Missing Values Heatmap")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %%
if "customer_state" in df.columns:
    sns.countplot(
        data=df,
        x="customer_state",
        order=df["customer_state"].value_counts().index
    )

    plt.title("Orders by Customer State")
    plt.xlabel("Customer State")
    plt.ylabel("Number of Orders")
    plt.xticks(rotation=45)
    plt.show()

# %%
if "main_product_category" in df.columns:
    top_categories = df["main_product_category"].value_counts().head(15).index

    sns.countplot(
        data=df[df["main_product_category"].isin(top_categories)],
        y="main_product_category",
        order=top_categories
    )

    plt.title("Top Product Categories")
    plt.xlabel("Number of Orders")
    plt.ylabel("Product Category")
    plt.show()

# %%
if "delivery_speed_category" in df.columns:
    delivery_order = [
        "Fast",
        "Normal",
        "Slow",
        "Very Delayed"
    ]

    sns.countplot(
        data=df,
        x="delivery_speed_category",
        order=delivery_order
    )

    plt.title("Delivery Speed Category Distribution")
    plt.xlabel("Delivery Speed Category")
    plt.ylabel("Number of Orders")
    plt.show()

# %%
if "total_payment_value" in df.columns:
    sns.histplot(
        data=df,
        x="total_payment_value",
        bins=50,
        kde=True
    )

    plt.title("Distribution of Total Payment Value")
    plt.xlabel("Total Payment Value")
    plt.ylabel("Frequency")
    plt.show()

# %%
if "delivery_days" in df.columns:
    sns.histplot(
        data=df,
        x="delivery_days",
        bins=40,
        kde=True
    )

    plt.title("Distribution of Delivery Days")
    plt.xlabel("Delivery Days")
    plt.ylabel("Frequency")
    plt.show()

# %%
skew_cols = [
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "delivery_delay_days",
    "total_items"
]

skew_cols = keep_existing_columns(df, skew_cols)

skewness_values = df[skew_cols].skew().sort_values(ascending=False)

skewness_values
# Out:
# total_freight          12.052723
# total_price             9.727741
# total_payment_value     9.150169
# total_items             7.527006
# delivery_days           3.828790
# delivery_delay_days     2.014360
# dtype: float64

# %%
sns.barplot(
    x=skewness_values.values,
    y=skewness_values.index
)

plt.title("Skewness of Numerical Features")
plt.xlabel("Skewness")
plt.ylabel("Feature")
plt.show()

# %%
if "total_payment_value" in df.columns:
    sns.boxplot(
        data=df,
        y="total_payment_value"
    )

    plt.title("Box Plot of Total Payment Value")
    plt.ylabel("Total Payment Value")
    plt.show()

# %%
if "delivery_days" in df.columns:
    sns.boxplot(
        data=df,
        y="delivery_days"
    )

    plt.title("Box Plot of Delivery Days")
    plt.ylabel("Delivery Days")
    plt.show()

# %%
def iqr_outlier_summary(dataframe, column):

    q1 = dataframe[column].quantile(0.25)
    q3 = dataframe[column].quantile(0.75)

    iqr = q3 - q1

    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    outliers = dataframe[
        (dataframe[column] < lower_bound) |
        (dataframe[column] > upper_bound)
    ]

    summary = {
        "column": column,
        "q1": q1,
        "q3": q3,
        "iqr": iqr,
        "lower_bound": lower_bound,
        "upper_bound": upper_bound,
        "outlier_count": len(outliers),
        "outlier_percent": (len(outliers) / len(dataframe)) * 100
    }

    return summary

# %%
if "total_payment_value" in df.columns:
    iqr_outlier_summary(df, "total_payment_value")

# %%
print(iqr_outlier_summary(df, "total_payment_value"))
# Out:
# {'column': 'total_payment_value', 'q1': np.float64(62.01), 'q3': np.float64(176.97), 'iqr': np.float64(114.96000000000001), 'lower_bound': np.float64(-110.43), 'upper_bound': np.float64(349.40999999999997), 'outlier_count': 7866, 'outlier_percent': 7.910218119286813}

# %%
if "delivery_days" in df.columns:
    print(iqr_outlier_summary(df, "delivery_days"))
# Out:
# {'column': 'delivery_days', 'q1': np.float64(6.0), 'q3': np.float64(15.0), 'iqr': np.float64(9.0), 'lower_bound': np.float64(-7.5), 'upper_bound': np.float64(28.5), 'outlier_count': 5025, 'outlier_percent': 5.053247654388029}

# %%
if {"delivery_delay_days", "review_score"}.issubset(df.columns):

    plt.figure(figsize=(8,6))

    sns.scatterplot(
        data=df,
        x="delivery_delay_days",
        y="review_score",
        alpha=0.5
    )

    plt.title("Delivery Delay vs Review Score")
    plt.xlabel("Delivery Delay Days")
    plt.ylabel("Review Score")

    plt.show()

# %%
if {
    "total_payment_value",
    "total_freight",
    "is_late_delivery"
}.issubset(df.columns):

    plt.figure(figsize=(8,6))

    sns.scatterplot(
        data=df,
        x="total_payment_value",
        y="total_freight",
        hue="is_late_delivery",
        alpha=0.6
    )

    plt.title("Payment Value vs Freight Cost")
    plt.xlabel("Total Payment Value")
    plt.ylabel("Total Freight")

    plt.show()

# %%
if {
    "is_late_delivery",
    "review_score"
}.issubset(df.columns):

    plt.figure(figsize=(8,6))

    sns.boxplot(
        data=df,
        x="is_late_delivery",
        y="review_score"
    )

    plt.title("Review Score by Late Delivery")
    plt.xlabel("Late Delivery")
    plt.ylabel("Review Score")

    plt.show()

# %%
if {
    "is_late_delivery",
    "review_score"
}.issubset(df.columns):

    plt.figure(figsize=(8,6))

    sns.boxplot(
        data=df,
        x="is_late_delivery",
        y="review_score"
    )

    plt.title("Review Score by Late Delivery")
    plt.xlabel("Late Delivery")
    plt.ylabel("Review Score")

    plt.show()

# %%
numeric_df = df.select_dtypes(include=["int64", "float64"])

correlation_matrix = numeric_df.corr()

correlation_matrix
# Out:
#                           order_year  order_month  order_day  \
# order_year                  1.000000    -0.550059  -0.043672
# order_month                -0.550059     1.000000   0.001343
# order_day                  -0.043672     0.001343   1.000000
# order_day_of_week          -0.017917     0.020588  -0.024895
# order_hour                 -0.003229    -0.003953  -0.012195
# delivery_days              -0.050156    -0.054398  -0.000528
# estimated_delivery_days    -0.142717    -0.094182  -0.030391
# delivery_delay_days         0.067070     0.025640   0.024665
# is_late_delivery            0.044052    -0.030097   0.007092
# review_score                0.004872     0.027560   0.001774
# is_low_review               0.000559    -0.023095  -0.001763
# review_comment_count       -0.020369    -0.009445  -0.002527
# has_review_comment         -0.019840    -0.008929  -0.002751
# total_payment_value        -0.000183     0.002795  -0.008652
# max_payment_installments   -0.059538     0.030311   0.001596
# payment_types_count        -0.019503     0.003532   0.002613
# total_items                 0.000211     0.000457   0.011453
# total_price                -0.002716     0.001993  -0.007884
# total_freight               0.027865     0.003800  -0.008286
# unique_products            -0.004688     0.009030   0.006638
# unique_sellers              0.017861     0.004820   0.002989
#
#                           order_day_of_week  order_hour  delivery_days  \
# order_year                        -0.017917   -0.003229      -0.050156
# order_month                        0.020588   -0.003953      -0.054398
# order_day                         -0.024895   -0.012195      -0.000528
# order_day_of_week                  1.000000    0.009433       0.028807
# order_hour                         0.009433    1.000000      -0.004758
# delivery_days                      0.028807   -0.004758       1.000000
# estimated_delivery_days            0.067685   -0.000144       0.382836
# delivery_delay_days               -0.031395    0.022651       0.607716
# is_late_delivery                  -0.011613    0.007205       0.603732
# review_score                      -0.008246    0.005765      -0.334150
# is_low_review                      0.003517   -0.006700       0.305947
# review_comment_count              -0.003897   -0.009375       0.085097
# has_review_comment                -0.004271   -0.009162       0.084981
# total_payment_value               -0.002538    0.004185       0.069496
# max_payment_installments           0.026230    0.013405       0.051852
# payment_types_count               -0.000564    0.005917       0.001487
# total_items                       -0.011766   -0.009770      -0.019167
# total_price                       -0.002625    0.004538       0.055466
# total_freight                     -0.002400    0.000074       0.167077
# unique_products                    0.004694    0.003316      -0.029999
# unique_sellers                     0.011540   -0.003613      -0.040664
#
#                           estimated_delivery_days  delivery_delay_days  \
# order_year                              -0.142717             0.067070
# order_month                             -0.094182             0.025640
# order_day                               -0.030391             0.024665
# order_day_of_week                        0.067685            -0.031395
# order_hour                              -0.000144             0.022651
# delivery_days                            0.382836             0.607716
# estimated_delivery_days                  1.000000            -0.499649
# delivery_delay_days                     -0.499649             1.000000
# is_late_delivery                        -0.033475             0.595474
# review_score                            -0.054533            -0.266990
# is_low_review                            0.042413             0.252709
# review_comment_count                     0.044501             0.042127
# has_review_comment                       0.043892             0.042589
# total_payment_value                      0.094915            -0.017743
# max_payment_installments                 0.094111            -0.030909
# payment_types_count                      0.011618            -0.008432
# total_items                              0.015000            -0.031915
# total_price                              0.076126            -0.013443
# total_freight                            0.237994            -0.049303
# unique_products                          0.022900            -0.047724
# unique_sellers                           0.023690            -0.059083
#
#                           is_late_delivery  review_score  ...  \
# order_year                        0.044052      0.004872  ...
# order_month                      -0.030097      0.027560  ...
# order_day                         0.007092      0.001774  ...
# order_day_of_week                -0.011613     -0.008246  ...
# order_hour                        0.007205      0.005765  ...
# delivery_days                     0.603732     -0.334150  ...
# estimated_delivery_days          -0.033475     -0.054533  ...
# delivery_delay_days               0.595474     -0.266990  ...
# is_late_delivery                  1.000000     -0.354495  ...
# review_score                     -0.354495      1.000000  ...
# is_low_review                     0.348880     -0.883055  ...
# review_comment_count              0.093407     -0.258592  ...
# has_review_comment                0.093849     -0.259388  ...
# total_payment_value               0.018104     -0.049137  ...
# max_payment_installments          0.012076     -0.031006  ...
# payment_types_count              -0.003983     -0.001868  ...
# total_items                      -0.014851     -0.115559  ...
# total_price                       0.016587     -0.039724  ...
# total_freight                     0.029797     -0.088623  ...
# unique_products                  -0.021231     -0.097079  ...
# unique_sellers                   -0.025332     -0.107921  ...
#
#                           review_comment_count  has_review_comment  \
# order_year                           -0.020369           -0.019840
# order_month                          -0.009445           -0.008929
# order_day                            -0.002527           -0.002751
# order_day_of_week                    -0.003897           -0.004271
# order_hour                           -0.009375           -0.009162
# delivery_days                         0.085097            0.084981
# estimated_delivery_days               0.044501            0.043892
# delivery_delay_days                   0.042127            0.042589
# is_late_delivery                      0.093407            0.093849
# review_score                         -0.258592           -0.259388
# is_low_review                         0.279705            0.281246
# review_comment_count                  1.000000            0.997057
# has_review_comment                    0.997057            1.000000
# total_payment_value                   0.042891            0.043362
# max_payment_installments              0.046845            0.046333
# payment_types_count                  -0.000525           -0.000504
# total_items                           0.057609            0.057588
# total_price                           0.038285            0.038736
# total_freight                         0.054868            0.055219
# unique_products                       0.052125            0.051759
# unique_sellers                        0.055772            0.055610
#
#                           total_payment_value  max_payment_installments  \
# order_year                          -0.000183                 -0.059538
# order_month                          0.002795                  0.030311
# order_day                           -0.008652                  0.001596
# order_day_of_week                   -0.002538                  0.026230
# order_hour                           0.004185                  0.013405
# delivery_days                        0.069496                  0.051852
# estimated_delivery_days              0.094915                  0.094111
# delivery_delay_days                 -0.017743                 -0.030909
# is_late_delivery                     0.018104                  0.012076
# review_score                        -0.049137                 -0.031006
# is_low_review                        0.055514                  0.034329
# review_comment_count                 0.042891                  0.046845
# has_review_comment                   0.043362                  0.046333
# total_payment_value                  1.000000                  0.319090
# max_payment_installments             0.319090                  1.000000
# payment_types_count                 -0.006926                 -0.042044
# total_items                          0.189216                  0.067573
# total_price                          0.995970                  0.314274
# total_freight                        0.492681                  0.199458
# unique_products                      0.077784                  0.072983
# unique_sellers                       0.052530                  0.061955
#
#                           payment_types_count  total_items  total_price  \
# order_year                          -0.019503     0.000211    -0.002716
# order_month                          0.003532     0.000457     0.001993
# order_day                            0.002613     0.011453    -0.007884
# order_day_of_week                   -0.000564    -0.011766    -0.002625
# order_hour                           0.005917    -0.009770     0.004538
# delivery_days                        0.001487    -0.019167     0.055466
# estimated_delivery_days              0.011618     0.015000     0.076126
# delivery_delay_days                 -0.008432    -0.031915    -0.013443
# is_late_delivery                    -0.003983    -0.014851     0.016587
# review_score                        -0.001868    -0.115559    -0.039724
# is_low_review                       -0.001024     0.114780     0.046987
# review_comment_count                -0.000525     0.057609     0.038285
# has_review_comment                  -0.000504     0.057588     0.038736
# total_payment_value                 -0.006926     0.189216     0.995970
# max_payment_installments            -0.042044     0.067573     0.314274
# payment_types_count                  1.000000    -0.006919    -0.007221
# total_items                         -0.006919     1.000000     0.153063
# total_price                         -0.007221     0.153063     1.000000
# total_freight                       -0.002118     0.436941     0.412786
# unique_products                      0.002758     0.470977     0.061311
# unique_sellers                       0.007066     0.282200     0.041463
#
#                           total_freight  unique_products  unique_sellers
# order_year                     0.027865        -0.004688        0.017861
# order_month                    0.003800         0.009030        0.004820
# order_day                     -0.008286         0.006638        0.002989
# order_day_of_week             -0.002400         0.004694        0.011540
# order_hour                     0.000074         0.003316       -0.003613
# delivery_days                  0.167077        -0.029999       -0.040664
# estimated_delivery_days        0.237994         0.022900        0.023690
# delivery_delay_days           -0.049303        -0.047724       -0.059083
# is_late_delivery               0.029797        -0.021231       -0.025332
# review_score                  -0.088623        -0.097079       -0.107921
# is_low_review                  0.085856         0.098228        0.108638
# review_comment_count           0.054868         0.052125        0.055772
# has_review_comment             0.055219         0.051759        0.055610
# total_payment_value            0.492681         0.077784        0.052530
# max_payment_installments       0.199458         0.072983        0.061955
# payment_types_count           -0.002118         0.002758        0.007066
# total_items                    0.436941         0.470977        0.282200
# total_price                    0.412786         0.061311        0.041463
# total_freight                  1.000000         0.194978        0.130456
# unique_products                0.194978         1.000000        0.592784
# unique_sellers                 0.130456         0.592784        1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(14,10))

sns.heatmap(
    correlation_matrix,
    cmap="coolwarm",
    annot=False,
    linewidths=0.5
)

plt.title("Correlation Heatmap")

plt.show()

# %%
if "is_late_delivery" in correlation_matrix.columns:

    target_corr = (
        correlation_matrix["is_late_delivery"]
        .sort_values(ascending=False)
    )

    print(target_corr)
# Out:
# is_late_delivery            1.000000
# delivery_days               0.603732
# delivery_delay_days         0.595474
# is_low_review               0.348880
# has_review_comment          0.093849
# review_comment_count        0.093407
# order_year                  0.044052
# total_freight               0.029797
# total_payment_value         0.018104
# total_price                 0.016587
# max_payment_installments    0.012076
# order_hour                  0.007205
# order_day                   0.007092
# payment_types_count        -0.003983
# order_day_of_week          -0.011613
# total_items                -0.014851
# unique_products            -0.021231
# unique_sellers             -0.025332
# order_month                -0.030097
# estimated_delivery_days    -0.033475
# review_score               -0.354495
# Name: is_late_delivery, dtype: float64

# %%
def keep_existing_columns(df, columns):
    return [col for col in columns if col in df.columns]

# %%
clean_df = df.copy()

# %%
if "delivery_days" in clean_df.columns:
    clean_df["missing_delivery_days"] = clean_df["delivery_days"].isnull().astype(int)

# %%
categorical_missing_cols = [
    "main_product_category",
    "dominant_payment_type",
    "delivery_speed_category",
    "payment_value_band",
    "customer_state",
    "customer_city",
    "order_status"
]

categorical_missing_cols = keep_existing_columns(
    clean_df,
    categorical_missing_cols
)

for col in categorical_missing_cols:
    if str(clean_df[col].dtype) == "category":
        if "Unknown" not in clean_df[col].cat.categories:
            clean_df[col] = clean_df[col].cat.add_categories(["Unknown"])

    clean_df[col] = clean_df[col].fillna("Unknown")

# %%
numerical_missing_cols = [
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "estimated_delivery_days",
    "delivery_delay_days",
    "review_score",
    "total_items",
    "unique_products",
    "unique_sellers"
]

numerical_missing_cols = keep_existing_columns(
    clean_df,
    numerical_missing_cols
)

for col in numerical_missing_cols:
    clean_df[col] = clean_df[col].fillna(
        clean_df[col].median()
    )

# %%
if "total_payment_value" in clean_df.columns:
    clean_df["log_total_payment_value"] = np.log1p(
        clean_df["total_payment_value"]
    )

if "total_freight" in clean_df.columns:
    clean_df["log_total_freight"] = np.log1p(
        clean_df["total_freight"]
    )

if "total_price" in clean_df.columns:
    clean_df["log_total_price"] = np.log1p(
        clean_df["total_price"]
    )

# %%
if {
    "total_payment_value",
    "log_total_payment_value"
}.issubset(clean_df.columns):

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    sns.histplot(
        data=clean_df,
        x="total_payment_value",
        bins=50,
        kde=True,
        ax=axes[0]
    )

    axes[0].set_title("Original Total Payment Value")

    sns.histplot(
        data=clean_df,
        x="log_total_payment_value",
        bins=50,
        kde=True,
        ax=axes[1]
    )

    axes[1].set_title("Log-Transformed Total Payment Value")

    plt.tight_layout()
    plt.show()

# %%
scale_check_cols = [
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "total_items"
]

scale_check_cols = keep_existing_columns(clean_df, scale_check_cols)

clean_df[scale_check_cols].describe()
# Out:
#        total_payment_value   total_price  total_freight  delivery_days  \
# count         99441.000000  99441.000000   99441.000000   99441.000000
# mean            160.989707    137.357742      22.779500      12.031647
# std             221.950211    209.870343      21.572104       9.415006
# min               0.000000      0.850000       0.000000       0.000000
# 25%              62.010000     45.990000      13.900000       6.000000
# 50%             105.290000     86.900000      17.170000      10.000000
# 75%             176.970000    149.900000      23.920000      15.000000
# max           13664.080000  13440.000000    1794.960000     209.000000
#
#         total_items
# count  99441.000000
# mean       1.140626
# std        0.536495
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       21.000000

# %%
def keep_existing_columns(df, columns):
    return [col for col in columns if col in df.columns]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

scaling_cols = [
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "total_items"
]

scaling_cols = keep_existing_columns(clean_df, scaling_cols)

standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
robust_scaler = RobustScaler()

standard_scaled = standard_scaler.fit_transform(clean_df[scaling_cols])

minmax_scaled = minmax_scaler.fit_transform(clean_df[scaling_cols])

robust_scaled = robust_scaler.fit_transform(clean_df[scaling_cols])

standard_scaled_df = pd.DataFrame(
    standard_scaled,
    columns=[col + "_standard_scaled" for col in scaling_cols]
)

minmax_scaled_df = pd.DataFrame(
    minmax_scaled,
    columns=[col + "_minmax_scaled" for col in scaling_cols]
)

robust_scaled_df = pd.DataFrame(
    robust_scaled,
    columns=[col + "_robust_scaled" for col in scaling_cols]
)

standard_scaled_df.head()
# Out:
#    total_payment_value_standard_scaled  total_price_standard_scaled  \
# 0                            -0.550936                    -0.511593
# 1                            -0.087992                    -0.088902
# 2                             0.081687                     0.107411
# 3                            -0.400045                    -0.440073
# 4                            -0.596397                    -0.559671
#
#    total_freight_standard_scaled  delivery_days_standard_scaled  \
# 0                      -0.651748                      -0.428217
# 1                      -0.000904                       0.102853
# 2                      -0.165006                      -0.322003
# 3                       0.204918                       0.102853
# 4                      -0.651748                      -1.065501
#
#    total_items_standard_scaled
# 0                    -0.262121
# 1                    -0.262121
# 2                    -0.262121
# 3                    -0.262121
# 4                    -0.262121

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\lilan\AppData\Local\Programs\Python\Python312\python.exe

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn
print("scikit-learn version:", sklearn.__version__)
# Out:
# scikit-learn version: 1.9.0

# %%
leakage_columns = [
    "delivery_delay_days",
    "delivery_speed_category"
]

# %%
clean_df.to_csv("../data/processed/olist_orders_abt_cleaned.csv", index=False)

print("Cleaned ABT saved successfully.")
print(clean_df.shape)
# Out:
# Cleaned ABT saved successfully.
# (99441, 35)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in C:\Users\lilan\AppData\Local\Programs\Python\Python312\Lib\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
