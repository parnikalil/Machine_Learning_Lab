# %% [markdown]
# #LAB 1 : Understanding the Olist E-Commerce Dataset
#
# **Prepared by : Parnika Lilani**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",100)

# %%
DATA_DAR= Path("../data/raw")

# %%
DATA_DAR.exists()
# Out:
# True

# %%
for file in DATA_DAR.glob("*.cvs"):
    print(file.name)

# %%
print(DATA_DAR)
# Out:
# ..\data\raw

# %%
import os
print(os.listdir(DATA_DAR))
# Out:
# ['olist_customers_dataset.csv', 'olist_geolocation_dataset.csv', 'olist_orders_dataset.csv', 'olist_order_items_dataset.csv', 'olist_order_payments_dataset.csv', 'olist_order_reviews_dataset.csv', 'olist_products_dataset.csv', 'olist_sellers_dataset.csv', 'product_category_name_translation.csv']

# %%
for file in DATA_DAR.glob("*.csv"):
    print(file.name)
# Out:
# olist_customers_dataset.csv
# olist_geolocation_dataset.csv
# olist_orders_dataset.csv
# olist_order_items_dataset.csv
# olist_order_payments_dataset.csv
# olist_order_reviews_dataset.csv
# olist_products_dataset.csv
# olist_sellers_dataset.csv
# product_category_name_translation.csv

# %%
customers = pd.read_csv(DATA_DAR / "olist_customers_dataset.csv")
geolocation = pd.read_csv(DATA_DAR / "olist_geolocation_dataset.csv")
order_items = pd.read_csv(DATA_DAR / "olist_order_items_dataset.csv")
payments = pd.read_csv(DATA_DAR / "olist_order_payments_dataset.csv")
reviews = pd.read_csv(DATA_DAR / "olist_order_reviews_dataset.csv")
orders = pd.read_csv(DATA_DAR / "olist_orders_dataset.csv")
products = pd.read_csv(DATA_DAR / "olist_products_dataset.csv")
sellers = pd.read_csv(DATA_DAR / "olist_sellers_dataset.csv")
category_translation = pd.read_csv(DATA_DAR / "product_category_name_translation.csv")

# %%
tables = {
    "customers": customers,
    "geolocation": geolocation,
    "order_items": order_items,
    "payments": payments,
    "reviews": reviews,
    "orders": orders,
    "products": products,
    "sellers": sellers,
    "category_translation": category_translation
}

# %%
for name, df in tables.items():
    print(f"{name}: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# customers: 99441 rows, 5 columns
# geolocation: 1000163 rows, 5 columns
# order_items: 112650 rows, 7 columns
# payments: 103886 rows, 5 columns
# reviews: 99224 rows, 7 columns
# orders: 99441 rows, 8 columns
# products: 32951 rows, 9 columns
# sellers: 3095 rows, 4 columns
# category_translation: 71 rows, 2 columns

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
for name, df in tables.items():
    print("\n" + "=" * 80)
    print(name.upper())
    print("=" * 80)
    df.info()
# Out:
# ...
# CUSTOMERS
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
#
# ...
# GEOLOCATION
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
# ...

# %%
def summarize_table(name, df):
    return {
        "table_name": name,
        "rows": df.shape[0],
        "columns": df.shape[1],
        "missing_values": df.isnull().sum().sum(),
        "duplicate_rows": df.duplicated().sum()
    }

summary = pd.DataFrame(
    [summarize_table(name, df) for name, df in tables.items()]
)

summary
# Out:
#              table_name     rows  columns  missing_values  duplicate_rows
# 0             customers    99441        5               0               0
# 1           geolocation  1000163        5               0          261831
# 2           order_items   112650        7               0               0
# 3              payments   103886        5               0               0
# 4               reviews    99224        7          145903               0
# 5                orders    99441        8            4908               0
# 6              products    32951        9            2448               0
# 7               sellers     3095        4               0               0
# 8  category_translation       71        2               0               0

# %%
summary.to_csv("../reports/lab01_dataset_summary.csv", index=False)

# %%
def missing_value_summary(df):
    missing_count = df.isnull().sum()
    missing_percent = (missing_count / len(df)) * 100

    result = pd.DataFrame({
        "missing_count": missing_count,
        "missing_percent": missing_percent
    })

    return result[result["missing_count"] > 0].sort_values(
        by="missing_percent",
        ascending=False
    )

# %%
for name, df in tables.items():
    print("\n" + "=" * 80)
    print(f"Missing Values in {name}")
    print("=" * 80)
    display(missing_value_summary(df))
# Out:
# ...
# Missing Values in customers
# ...
# Empty DataFrame
# Columns: [missing_count, missing_percent]
# Index: []
# ...
# Missing Values in geolocation
# ...
# Empty DataFrame
# Columns: [missing_count, missing_percent]
# Index: []
# ...
# Missing Values in order_items
# ...
# Empty DataFrame
# Columns: [missing_count, missing_percent]
# Index: []
# ...
# Missing Values in payments
# ...
# Empty DataFrame
# Columns: [missing_count, missing_percent]
# Index: []
# ...
# Missing Values in reviews
# ...
#                         missing_count  missing_percent
# review_comment_title            87656        88.341530
# review_comment_message          58247        58.702532
# ...
# Missing Values in orders
# ...
#                                missing_count  missing_percent
# order_delivered_customer_date           2965         2.981668
# order_delivered_carrier_date            1783         1.793023
# order_approved_at                        160         0.160899
# ...
# Missing Values in products
# ...
#                             missing_count  missing_percent
# ...

# %%
for name, df in tables.items():
    duplicate_count = df.duplicated().sum()
    print(f"{name}: {duplicate_count} duplicate rows")
# Out:
# customers: 0 duplicate rows
# geolocation: 261831 duplicate rows
# order_items: 0 duplicate rows
# payments: 0 duplicate rows
# reviews: 0 duplicate rows
# orders: 0 duplicate rows
# products: 0 duplicate rows
# sellers: 0 duplicate rows
# category_translation: 0 duplicate rows

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))

orders["order_status"].value_counts().plot(kind="bar")

plt.title("Order Status Distribution")
plt.xlabel("Order Status")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))

orders["order_status"].value_counts().plot(kind="bar")

plt.title("Order Status Distribution")
plt.xlabel("Order Status")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig("../figures/lab01_order_status_distribution.png")

plt.show()

# %%
reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
reviews["review_score"].value_counts().sort_index()
# Out:
# review_score
# 1    11424
# 2     3151
# 3     8179
# 4    19142
# 5    57328
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))

reviews["review_score"].value_counts().sort_index().plot(kind="bar")

plt.title("Review Score Distribution")
plt.xlabel("Review Score")
plt.ylabel("Number of Reviews")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))

reviews["review_score"].value_counts().sort_index().plot(kind="bar")

plt.title("Review Score Distribution")
plt.xlabel("Review Score")
plt.ylabel("Number of Reviews")

plt.tight_layout()

plt.savefig("../figures/lab01_review_score_distribution.png")

plt.show()

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
payments["payment_type"].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))

payments["payment_type"].value_counts().plot(kind="bar")

plt.title("Payment Type Distribution")
plt.xlabel("Payment Type")
plt.ylabel("Number of Payments")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
missing_value_summary(products)
# Out:
#                             missing_count  missing_percent
# product_category_name                 610         1.851234
# product_name_lenght                   610         1.851234
# product_description_lenght            610         1.851234
# product_photos_qty                    610         1.851234
# product_weight_g                        2         0.006070
# product_length_cm                       2         0.006070
# product_height_cm                       2         0.006070
# product_width_cm                        2         0.006070

# %%
products["product_category_name"].nunique()
# Out:
# 73

# %%
products["product_category_name"].value_counts().head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: count, dtype: int64

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers["customer_state"].value_counts().head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))

customers["customer_state"].value_counts().head(10).plot(kind="bar")

plt.title("Top 10 Customer States")
plt.xlabel("State")
plt.ylabel("Number of Customers")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Question 1: How many unique customers are present?

# %%
customers["customer_unique_id"].nunique()
# Out:
# 96096

# %% [markdown]
# Question 2: How many orders are present?

# %%
orders["order_id"].nunique()
# Out:
# 99441

# %% [markdown]
# Question 3: What are the most common order statuses?

# %%
orders["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %% [markdown]
# Question 4: What are the most common payment methods?

# %%
payments["payment_type"].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %% [markdown]
# Question 5: What is the average review score?

# %%
reviews["review_score"].mean()
# Out:
# np.float64(4.08642062404257)

# %%
Question 6: Which states have the most customers?

# %%
customers["customer_state"].value_counts().head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: count, dtype: int64

# %% [markdown]
# Task 18: Identify Potential Machine Learning Problems

# %% [markdown]
# | ML Problem                                      | Type                        | Possible Target         |
# | ----------------------------------------------- | --------------------------- | ----------------------- |
# | Predict whether an order will be delivered late | Classification              | Late / Not Late         |
# | Predict customer review score                   | Regression / Classification | `review_score`          |
# | Predict payment value                           | Regression                  | `payment_value`         |
# | Recommend product categories                    | Recommendation              | `product_category_name` |
# | Forecast monthly sales                          | Time Series Forecasting     | Monthly Revenue         |

# %% [markdown]
# Task 19: Create Initial Data Dictionary

# %% [markdown]
# 1. Customers Table
# | Table     | Column                   | Data Type | Description                            | Example Value |
# | --------- | ------------------------ | --------- | -------------------------------------- | ------------- |
# | customers | customer_id              | String    | Unique customer identifier             | abc123        |
# | customers | customer_unique_id       | String    | Unique customer across multiple orders | 8d50f5...     |
# | customers | customer_zip_code_prefix | Integer   | Customer ZIP code prefix               | 14409         |
# | customers | customer_city            | String    | Customer city                          | sao paulo     |
# | customers | customer_state           | String    | Customer state                         | SP            |

# %% [markdown]
# 2. Orders Table
# | Table  | Column                        | Data Type | Description                   | Example Value |
# | ------ | ----------------------------- | --------- | ----------------------------- | ------------- |
# | orders | order_id                      | String    | Unique order identifier       | e481f51...    |
# | orders | customer_id                   | String    | Customer who placed the order | abc123        |
# | orders | order_status                  | String    | Current order status          | delivered     |
# | orders | order_purchase_timestamp      | Datetime  | Purchase date and time        | 2017-10-02    |
# | orders | order_delivered_customer_date | Datetime  | Delivery date                 | 2017-10-10    |

# %% [markdown]
# 3. Order Items Table
# | Table       | Column        | Data Type | Description                  | Example Value |
# | ----------- | ------------- | --------- | ---------------------------- | ------------- |
# | order_items | order_id      | String    | Order identifier             | e481f51...    |
# | order_items | order_item_id | Integer   | Item number within the order | 1             |
# | order_items | product_id    | String    | Product identifier           | 87285b...     |
# | order_items | seller_id     | String    | Seller identifier            | 3504c0...     |
# | order_items | price         | Float     | Product price                | 58.90         |
# | order_items | freight_value | Float     | Shipping charge              | 13.29         |
